# %% [markdown]
# <span style='font-size: 30px'> **Задача 1** </span>

# %% [markdown]
# ![image.png](attachment:0622487e-88c3-4e7f-add4-da2e9f9d6bf8.png)

# %% [markdown]
# ![image.png](attachment:2efd0f3c-c7ae-454c-b058-b6218c1db7f3.png)

# %% [markdown]
# Вывод: судя по номерам последовательностей и расстояниям между ними на дереве, последовательности с близкими номерами располагаются близко на дереве.

# %% [markdown]
# <span style='font-size: 30px'> **Задача 2** </span>

# %% [markdown]
# Нашли в NCBI 6 ортологов коллагена COL3A1.

# %% [markdown]
# ![image.png](attachment:a3b44aa8-1a22-496c-a853-6f72889782ed.png)

# %% [markdown]
# ![image.png](attachment:e4ef6a30-9751-4c45-b9a4-7637cc4c233f.png)

# %% [markdown]
# Вывод: наиболее близкими родственниками оказались кабан (Sus scrofa) и бык (Bos taurus), так как они парнокопытные. Обезьяна (Macaca mulata) и человек (Homo sapiens) также оказались близки, так как они относятся к приматам. Наиболее дальним видом является курица (Gallus gallus), так как это единственная птица, а не млекопитающее.
